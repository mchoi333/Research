# %% [markdown]
# # Research Project

# %% [markdown]
# Michael Choi

# %% [markdown]
# The purpose of this project is to determine the distribution of NFL scoring plays. Can we model the true distribution simply using the historical final score data or can we model the individual scoring plays themselves? Can we create a model to predict the final score based on the spread, total, and aggression ratings of the two teams?

# %%
import numpy as np
import pandas as pd
import altair as alt
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# ## Final Digits of Each Quarter Analysis

# %% [markdown]
# We will start by modeling the historical data of scores. For simplicity, we will look at the final digits of scores for each quarter.

# %%
qtr = pd.read_csv('/Users/MC/Downloads/quarters.csv')
qtr
# Out:
#       season  week   game_date team place  qtr1  qtr2  qtr3  qtr4  ot  \
# 0       2013     1  2013-09-05  BAL  away     7    10     0    10 NaN
# 1       2013     1  2013-09-05  DEN  home     0    14    21    14 NaN
# 2       2013     1  2013-09-08  ARI  away     0    10    14     0 NaN
# 3       2013     1  2013-09-08   LA  home     0    10     3    14 NaN
# 4       2013     1  2013-09-08  ATL  away    10     0     7     0 NaN
# ...      ...   ...         ...  ...   ...   ...   ...   ...   ...  ..
# 5745    2023    12  2023-11-23  SEA  home     3     0    10     0 NaN
# 5746    2023    12  2023-11-23  WAS  away     0    10     0     0 NaN
# 5747    2023    12  2023-11-23  DAL  home     7    13     0    25 NaN
# 5748    2023    12  2023-11-24  MIA  away     3    14     3    14 NaN
# 5749    2023    12  2023-11-24  NYJ  home     0     6     0     7 NaN
#
#       spread_line  total_line  half  full
# 0             7.5        48.5    17    27
# 1             7.5        48.5    14    49
# 2             3.5        42.5    10    24
# 3             3.5        42.5    10    27
# 4             3.5        54.5    10    17
# ...           ...         ...   ...   ...
# 5745         -7.0        43.5     3    13
# 5746         13.0        48.0    10    10
# 5747         13.0        48.0    20    45
# 5748         -9.5        40.0    17    34
# 5749         -9.5        40.0     6    13
#
# [5750 rows x 14 columns]

# %% [markdown]
# We will make a dataframe containing the last digit of scores for each quarter. Put these dataframes into a list called q. We will also make a list of strings to pull from.

# %%
strings = ['qtr1','qtr2','qtr3','qtr4','ot']
q = [0]*(len(strings)+1)

for i in range(1,len(strings)+1):
    q[i] = pd.DataFrame((qtr[strings[i-1]]%10).value_counts().sort_index()).reset_index()

# %% [markdown]
# For each quarter, we will make a bar chart with the numbers 0 to 9 on the x-axis. On the y axis, we will record the frequency that a final scores has a last digit with the number on the x-axis.

# %%
quarters = [q[1],q[2],q[3],q[4],q[5]]
quarter = [0]*(len(quarters)+1)
colors = ['darkred','darkblue','darkorange','purple','darkgreen']

for i in range(1,len(quarters)+1):
    quarter[i] = alt.Chart(quarters[i-1]).mark_bar().encode(
        x = alt.X(f'{strings[i-1]}:N',axis=alt.Axis(labelAngle=0), title = 'Squares'),
        y = alt.Y('count', title = 'Frequency'),
        tooltip= strings[i-1],
        color = alt.value(colors[i-1])
    ).properties(
        title = f'Quarter {i}',
        height=300,
        width=600,
    )
quarter[5] = quarter[5].properties(title = 'Overtime')

# %%
alt.vconcat(quarter[1], quarter[2], quarter[3], quarter[4], quarter[5])
# Out:
# alt.VConcatChart(...)

# %% [markdown]
# ## Predict Final Outcome using Aggression Scores

# %% [markdown]
# We are also interested in predicting the final score of a game based on how aggressive a team is. We expect more aggressive teams to attempt to score in situations where less aggressive teams would choose to end their possession in fear of allowing the other team to score easily. In particular, we will find the number of fourth-down attempts and two-point conversion attempts. In addition, more aggressive teams will likely pass the ball for high yardage. These three parameters will assign an aggression score to each of the 32 NFL teams. Using, Feature Engineering, we can create a parameter to help predict the odds of winning.

# %%
all_plays_2023 = pd.read_csv('/Users/MC/Downloads/play_by_play_2023.csv')
all_plays_2023['fourth_down_attempts'] = all_plays_2023['fourth_down_converted'] + all_plays_2023['fourth_down_failed']
all_plays_2023['two_point_conv_result2']= all_plays_2023['two_point_conv_result'].map(lambda x: True if x == 'success' else False)
all_plays_2023
# Out:
# /var/folders/8y/bzk4l8dd4d9bqpf55d58_f240000gn/T/ipykernel_2443/2950946296.py:1: DtypeWarning: Columns (179,180,182,183,189,190,197,198,203,204,205,206,218,219,220,222,224,226,253,254,255,260,262,263,283,284,332) have mixed types. Specify dtype option on import or set low_memory=False.
#   all_plays_2023 = pd.read_csv('/Users/MC/Downloads/play_by_play_2023.csv')
#        play_id          game_id  old_game_id home_team away_team season_type  \
# 0            1  2023_01_ARI_WAS   2023091007       WAS       ARI         REG
# 1           39  2023_01_ARI_WAS   2023091007       WAS       ARI         REG
# 2           55  2023_01_ARI_WAS   2023091007       WAS       ARI         REG
# 3           77  2023_01_ARI_WAS   2023091007       WAS       ARI         REG
# 4          102  2023_01_ARI_WAS   2023091007       WAS       ARI         REG
# ...        ...              ...          ...       ...       ...         ...
# 48420     4253  2023_19_PIT_BUF   2024011501       BUF       PIT        POST
# 48421     4278  2023_19_PIT_BUF   2024011501       BUF       PIT        POST
# 48422     4322  2023_19_PIT_BUF   2024011501       BUF       PIT        POST
# 48423     4349  2023_19_PIT_BUF   2024011501       BUF       PIT        POST
# 48424     4371  2023_19_PIT_BUF   2024011501       BUF       PIT        POST
#
#        week posteam posteam_type defteam  ...    qb_epa  xyac_epa  \
# 0         1     NaN          NaN     NaN  ...  0.000000       NaN
# 1         1     WAS         home     ARI  ...  0.000000       NaN
# 2         1     WAS         home     ARI  ... -0.336103       NaN
# 3         1     WAS         home     ARI  ...  0.703308  0.340652
# 4         1     WAS         home     ARI  ...  0.469799       NaN
# ...     ...     ...          ...     ...  ...       ...       ...
# 48420    19     PIT         away     BUF  ...  0.097917  0.642515
# 48421    19     PIT         away     BUF  ... -0.858869       NaN
# 48422    19     PIT         away     BUF  ... -0.316456       NaN
# 48423    19     PIT         away     BUF  ... -1.543516       NaN
# 48424    19     PIT         away     BUF  ...       NaN       NaN
#
#       xyac_mean_yardage  xyac_median_yardage  xyac_success   xyac_fd  \
# 0                   NaN                  NaN           NaN       NaN
# 1                   NaN                  NaN           NaN       NaN
# 2                   NaN                  NaN           NaN       NaN
# 3              3.328642                  1.0      0.996628  0.583928
# 4                   NaN                  NaN           NaN       NaN
# ...                 ...                  ...           ...       ...
# 48420          5.621778                  4.0      0.988080  0.249705
# 48421               NaN                  NaN           NaN       NaN
# 48422               NaN                  NaN           NaN       NaN
# 48423               NaN                  NaN           NaN       NaN
# 48424               NaN                  NaN           NaN       NaN
#
#           xpass    pass_oe  fourth_down_attempts  two_point_conv_result2
# 0           NaN        NaN                   NaN                   False
# 1           NaN        NaN                   0.0                   False
# 2      0.515058 -51.505846                   0.0                   False
# 3      0.661106  33.889407                   0.0                   False
# 4      0.196065 -19.606467                   0.0                   False
# ...         ...        ...                   ...                     ...
# 48420  0.962465   3.753471                   0.0                   False
# 48421  0.968867   3.113294                   0.0                   False
# 48422  0.940734   5.926609                   0.0                   False
# 48423  0.962551   3.744876                   0.0                   False
# 48424       NaN        NaN                   NaN                   False
#
# [48425 rows x 374 columns]

# %% [markdown]
# We will use the first 15 weeks of an NFL season as a training set. We are most interested in how often a team goes for a fourth down conversion with more than 5 minutes to go between the NOT between the 30 and 40-yard line. If a team is within 30 yards, it would be more aggressive to try to go for a conversion rather than the safe option of kicking a field goal. Similarly, if a team is beyond the 40-yard line, we want to see how often they go for a conversion on fourth down rather than the safe option of punting the ball.  We note that the 30 and 40-yard line "dead man's zone" is arbitrarily created. A future extension of this project is to determine what bounds make the most sense for this area.

# %%
plays_2023 = all_plays_2023[['season_type','game_id','week','posteam','side_of_field','game_seconds_remaining','home_team','away_team','yards_gained','yardline_100','down','play_type','pass_length','air_yards','fourth_down_attempts','fourth_down_converted','two_point_attempt','two_point_conv_result2','spread_line','total_line']].copy()
train = plays_2023[(plays_2023["week"] <= 15) & (plays_2023["game_seconds_remaining"] >= 300) & ((plays_2023["yardline_100"] < 30) | (plays_2023["yardline_100"] > 40))].copy()
train['two_point_conv_result2']= train['two_point_conv_result2'].map(lambda x: True if x == 'success' else False)
train = train.fillna(0)

# %% [markdown]
# We will create an index call go to determine how often a team goes for a fourth down conversion NOT between the 30 and 40 yard line with more than 5 mins to go. In all a close game with less than 5 minutes left, a team is likely to attempt a conversion regardless of how truly aggresive they are. Between 30 and 40 yards, it is simillar to a no mans land where it makes sense to go for an attempt since the opposing team will still have a lot of yardage to cover in a turnover and your team is likely too far for a field goal attempt. The are between 30 and 40 yards is not defenitive and a possible follow up of this research can model what the true no mans land yardage are should be.

# %%
four_down = train[train['down'] == 4].copy()
four_down['play'] = four_down['play_type'].map(lambda x: 1 if x == 'pass' or x == 'run' else 0)
plays = four_down.groupby('posteam', as_index = False).sum(numeric_only = True)
fourths = four_down.groupby('posteam',as_index = False).count()
fourths['go'] = plays['play']
fourths['prop'] = plays['play']/fourths['play']
go = fourths.set_index('posteam')['prop']

# %%
teams = pd.DataFrame(train[train['air_yards'] > 20].groupby('posteam').count()['pass_length'])
teams['two_point_attempt'] = train[plays_2023['two_point_attempt'] == 1].groupby('posteam').count()['two_point_attempt']
teams['fourth_down_attempt'] = train[plays_2023['fourth_down_attempts'] == 1].groupby('posteam').count()['fourth_down_attempts']
# Out:
# /var/folders/8y/bzk4l8dd4d9bqpf55d58_f240000gn/T/ipykernel_2443/307433357.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   teams['two_point_attempt'] = train[plays_2023['two_point_attempt'] == 1].groupby('posteam').count()['two_point_attempt']
# /var/folders/8y/bzk4l8dd4d9bqpf55d58_f240000gn/T/ipykernel_2443/307433357.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   teams['fourth_down_attempt'] = train[plays_2023['fourth_down_attempts'] == 1].groupby('posteam').count()['fourth_down_attempts']

# %% [markdown]
# Below is a data frame of each team and their aggression score. The most aggressive team is Arizona as they had 10 two-point attempts, 18 fourth down attempts, and a 20 percent go rate for aggressive fourth down attempts. Jacksonville would be seen as 78% as aggressive as Arizona in this table.

# %%
teams = teams.rename_axis('team').reset_index()
teams = teams.fillna(0)
teams = teams.rename(columns={"pass_length": "deep_passes"})
teams['go'] = teams['team'].map(go)
teams['score'] = teams['deep_passes'] + 5*teams['two_point_attempt'] + 2*teams['fourth_down_attempt'] + 200*teams['go']
teams['score'] = teams['score']/max(teams['score'])
teams.sort_values(['score'],ascending=False)
# Out:
#    team  deep_passes  two_point_attempt  fourth_down_attempt        go  \
# 0   ARI           29               10.0                   18  0.204545
# 14  JAX           43                3.0                   14  0.181818
# 25  PHI           43                2.0                   14  0.202899
# 7   CLE           46                5.0                   13  0.117117
# 13  IND           31                3.0                   18  0.189474
# 11   GB           38                4.0                   14  0.150538
# 10  DET           23                3.0                   16  0.222222
# 8   DAL           40                4.0                   11  0.159420
# 31  WAS           43                4.0                   11  0.135802
# 12  HOU           33                5.0                   13  0.132653
# 4   CAR           37                1.0                   17  0.161905
# 19  MIA           41                1.0                   12  0.181818
# 17  LAC           36                1.0                   15  0.176471
# 30  TEN           58                0.0                   10  0.113636
# 16   LA           39                4.0                    9  0.109756
# 23  NYG           31                2.0                   15  0.136364
# 3   BUF           41                1.0                   10  0.153846
# 1   ATL           37                2.0                   10  0.108696
# 22   NO           43                3.0                    7  0.082353
# 5   CHI           30                2.0                   10  0.126582
# 18   LV           33                1.0                   10  0.111111
# 24  NYJ           25                2.0                   11  0.097345
# 26  PIT           33                2.0                    8  0.085106
# 20  MIN           21                1.0                   10  0.140845
# 29   TB           35                1.0                    7  0.080460
# 27  SEA           44                1.0                    5  0.053763
# 9   DEN           38                2.0                    5  0.056818
# 15   KC           36                1.0                    5  0.073529
# 2   BAL           37                1.0                    5  0.062500
# 6   CIN           29                0.0                    8  0.085366
# 21   NE           31                1.0                    6  0.065934
# 28   SF           33                0.0                    3  0.049180
#
#        score
# 0   1.000000
# 14  0.784840
# 25  0.779812
# 7   0.772395
# 13  0.769004
# 11  0.744713
# 10  0.734046
# 8   0.730452
# 31  0.719397
# 12  0.708943
# 4   0.695155
# 19  0.682216
# 17  0.681770
# 30  0.646064
# 16  0.634673
# 23  0.630321
# 3   0.620677
# 1   0.569172
# 22  0.567450
# 5   0.547219
# 18  0.514545
# 24  0.490472
# 26  0.487600
# 20  0.475720
# 29  0.449569
# 27  0.447393
# 9   0.444898
# 15  0.421437
# 2   0.413703
# 6   0.398137
# 21  0.392452
# 28  0.313234

# %% [markdown]
# We will make a dictionary of each team and their aggression score.

# %%
agg = teams.set_index('team')['score']

# %% [markdown]
# We will make a games data frame with each game in the NFL season and the spread, total, and aggression scores of the home and away team.

# %%
games = plays_2023[plays_2023['season_type'] == 'REG'].groupby('game_id').first()
games_tries = plays_2023[plays_2023['season_type'] == 'REG'].groupby('game_id').sum(numeric_only = True)
games = games[['spread_line','total_line','away_team','home_team']]
games['two_point_attempts'] =games_tries['two_point_attempt']
games['two_point_try'] = games['two_point_attempts'].map(lambda x: 1 if x > .00001 else 0)
games = games.rename_axis('game').reset_index()
games['away_team_score'] = games['away_team'].map(agg)
games['home_team_score'] = games['home_team'].map(agg)
games = games[['game','spread_line','total_line','away_team_score','home_team_score','two_point_attempts','two_point_try']]
games
# Out:
#                 game  spread_line  total_line  away_team_score  \
# 0    2023_01_ARI_WAS          7.0        38.0         1.000000
# 1    2023_01_BUF_NYJ         -2.5        44.5         0.620677
# 2    2023_01_CAR_ATL          3.5        40.5         0.695155
# 3    2023_01_CIN_CLE         -1.0        46.5         0.398137
# 4    2023_01_DAL_NYG         -3.5        44.5         0.730452
# ..               ...          ...         ...              ...
# 267   2023_18_NYJ_NE          2.5        28.5         0.490472
# 268  2023_18_PHI_NYG         -4.5        43.0         0.779812
# 269  2023_18_PIT_BAL         -3.0        34.0         0.487600
# 270  2023_18_SEA_ARI         -2.5        48.0         0.447393
# 271   2023_18_TB_CAR         -5.0        36.5         0.449569
#
#      home_team_score  two_point_attempts  two_point_try
# 0           0.719397                 0.0              0
# 1           0.490472                 0.0              0
# 2           0.569172                 0.0              0
# 3           0.772395                 1.0              1
# 4           0.630321                 0.0              0
# ..               ...                 ...            ...
# 267         0.392452                 1.0              1
# 268         0.630321                 0.0              0
# 269         0.413703                 0.0              0
# 270         1.000000                 1.0              1
# 271         0.695155                 0.0              0
#
# [272 rows x 7 columns]

# %% [markdown]
# We will then fit the data with a Decision Tree Regression model with spread, total, and aggression scores being used to predict the probability of a two-point attempt.

# %%
X = games[['spread_line','total_line','away_team_score','home_team_score']]
y = games['two_point_try']
clf = DecisionTreeRegressor(max_depth=5)
clf.fit(X,y)
# Out:
# DecisionTreeRegressor(max_depth=5)

# %% [markdown]
# This is the spread, total, and aggression score for the Super Bowl 2024 matchup.

# %%
data = pd.DataFrame({"spread_line":[2],"total_line":[47.5],'away_team_score':agg['SF'],'home_team_score':agg['KC']})
data
# Out:
#    spread_line  total_line  away_team_score  home_team_score
# 0            2        47.5         0.313234         0.421437

# %%
p_super_try = clf.predict(data)[0]
p_super_try
# Out:
# 0.30344827586206896

# %%
(1-p_super_try)/p_super_try*100
# Out:
# 229.5454545454546

# %%
p_sucess = len(all_plays_2023[all_plays_2023['two_point_conv_result2'] ==  True])/len(all_plays_2023[all_plays_2023['two_point_attempt'] == 1])
p_sucess
# Out:
# 0.5538461538461539

# %%
p_super_sucess = p_super_try * p_sucess
p_super_sucess
# Out:
# 0.16806366047745358

# %%
((1-p_super_sucess)/p_super_sucess)*100
# Out:
# 495.0126262626263

# %% [markdown]
# We will now model the scoring distributions of games. In the cell below, all scoring play columns are added to a dataset of 2023 plays. We record separate columns for home and away field goals worth 3 points, and touchdowns worth 6 points with a separate column for the extra point and two-point conversion.

# %%
plays_2023 = all_plays_2023[['season_type','game_id','week','qtr','total_away_score','total_home_score','quarter_seconds_remaining','sp','posteam','defteam','side_of_field','home_team','away_team','td_team','touchdown','extra_point_result','two_point_conv_result','field_goal_result','total_home_score','total_away_score','desc','play_type','safety']].copy()
all_games = plays_2023[(plays_2023['sp'] == 1) | (plays_2023['extra_point_result'] == 'failed') | (plays_2023['two_point_conv_result'] == 'failure')].copy()
all_games['home_team_score'] = (all_games['td_team'] == all_games['home_team']).map(lambda x:  6 if x == True else 0)
all_games['away_team_score'] = (all_games['td_team'] == all_games['away_team']).map(lambda x:  6 if x == True else 0)
all_games['xp'] = all_games['extra_point_result'].map(lambda x:  1 if x == 'good' else 0).shift(-1).fillna(0)
all_games['2pt'] = all_games['two_point_conv_result'].map(lambda x:  2 if x == 'success' else 0).shift(-1).fillna(0)

homesafety = ((all_games['defteam'] == all_games['home_team']) & (all_games['safety'] == 1)).map(lambda x: 2 if x == True else 0)
awaysafety = ((all_games['defteam'] == all_games['away_team']) & (all_games['safety'] == 1)).map(lambda x: 2 if x == True else 0)
homekick = ((all_games['posteam'] == all_games['home_team']) & (all_games['field_goal_result'] == 'made')).map(lambda x:  3 if x == True else 0)
awaykick = ((all_games['posteam'] == all_games['away_team']) & (all_games['field_goal_result'] == 'made')).map(lambda x:  3 if x == True else 0)

two_h = ((homesafety == 2)).map(lambda x:  2 if x == True else 0)
three_h = ((homekick == 3)).map(lambda x:  3 if x == True else 0)
six_h = ((all_games['home_team_score'] == 6) & (all_games['xp'] == 0) & (all_games['2pt'] == 0)).map(lambda x:  6 if x == True else 0)
seven_h = ((all_games['home_team_score'] == 6) & (all_games['xp'] == 1)).map(lambda x:  7 if x == True else 0)
eight_h = ((all_games['home_team_score'] == 6) & (all_games['2pt'] == 2)).map(lambda x:  8 if x == True else 0)
all_games['home_score'] = two_h + three_h + six_h + seven_h + eight_h

two_a = ((awaysafety == 2)).map(lambda x:  2 if x == True else 0)
three_a = ((awaykick == 3)).map(lambda x:  3 if x == True else 0)
six_a = ((all_games['away_team_score'] == 6) & (all_games['xp'] == 0) & (all_games['2pt'] == 0)).map(lambda x:  6 if x == True else 0)
seven_a = ((all_games['away_team_score'] == 6) & (all_games['xp'] == 1)).map(lambda x:  7 if x == True else 0)
eight_a = ((all_games['away_team_score'] == 6) & (all_games['2pt'] == 2)).map(lambda x:  8 if x == True else 0)
all_games['away_score'] = two_a +three_a + six_a + seven_a + eight_a
all_games
# Out:
#       season_type          game_id  week  qtr total_away_score  \
# 25            REG  2023_01_ARI_WAS     1    1                0
# 26            REG  2023_01_ARI_WAS     1    1                0
# 36            REG  2023_01_ARI_WAS     1    1                3
# 46            REG  2023_01_ARI_WAS     1    2                6
# 79            REG  2023_01_ARI_WAS     1    2               12
# ...           ...              ...   ...  ...              ...
# 48370        POST  2023_19_PIT_BUF    19    3               10
# 48384        POST  2023_19_PIT_BUF    19    4               16
# 48385        POST  2023_19_PIT_BUF    19    4               17
# 48394        POST  2023_19_PIT_BUF    19    4               17
# 48395        POST  2023_19_PIT_BUF    19    4               17
#
#        total_home_score  quarter_seconds_remaining  sp posteam defteam  ...  \
# 25                    6                      262.0   1     WAS     ARI  ...
# 26                    7                      255.0   1     WAS     ARI  ...
# 36                    7                       56.0   1     ARI     WAS  ...
# 46                    7                      811.0   1     ARI     WAS  ...
# 79                    7                       62.0   1     WAS     ARI  ...
# ...                 ...                        ...  ..     ...     ...  ...
# 48370                24                       96.0   1     BUF     PIT  ...
# 48384                24                      637.0   1     PIT     BUF  ...
# 48385                24                      632.0   1     PIT     BUF  ...
# 48394                30                      397.0   1     BUF     PIT  ...
# 48395                31                      387.0   1     BUF     PIT  ...
#
#       total_away_score                                               desc  \
# 25                   0  (4:22) (Shotgun) 14-S.Howell pass short left t...
# 26                   0  6-J.Slye extra point is GOOD, Center-54-C.Chee...
# 36                   3  (:56) 5-M.Prater 28 yard field goal is GOOD, C...
# 46                   6  (13:31) 5-M.Prater 54 yard field goal is GOOD,...
# 79                  12  (1:02) (Shotgun) 14-S.Howell sacked at WAS 12 ...
# ...                ...                                                ...
# 48370               10  (1:36) 2-T.Bass 45 yard field goal is GOOD, Ce...
# 48384               16  (10:37) (Shotgun) 2-M.Rudolph pass short left ...
# 48385               17  9-C.Boswell extra point is GOOD, Center-46-C.K...
# 48394               17  (6:37) (Shotgun) 17-J.Allen pass short middle ...
# 48395               17  2-T.Bass extra point is GOOD, Center-69-R.Ferg...
#
#          play_type safety  home_team_score away_team_score   xp  2pt  \
# 25            pass    0.0                6               0  1.0  0.0
# 26     extra_point    0.0                0               0  0.0  0.0
# 36      field_goal    0.0                0               0  0.0  0.0
# 46      field_goal    0.0                0               0  0.0  0.0
# 79            pass    0.0                0               6  1.0  0.0
# ...            ...    ...              ...             ...  ...  ...
# 48370   field_goal    0.0                0               0  0.0  0.0
# 48384         pass    0.0                0               6  1.0  0.0
# 48385  extra_point    0.0                0               0  0.0  0.0
# 48394         pass    0.0                6               0  1.0  0.0
# 48395  extra_point    0.0                0               0  0.0  0.0
#
#        home_score  away_score
# 25              7           0
# 26              0           0
# 36              0           3
# 46              0           3
# 79              0           7
# ...           ...         ...
# 48370           3           0
# 48384           0           7
# 48385           0           0
# 48394           7           0
# 48395           0           0
#
# [3610 rows x 29 columns]

# %% [markdown]
# We will create a dictionary called scores. This dictionary tells us how many scoring plays occured in quarter 1 for the home and away team.

# %%
len_h = (all_games['home_score'] > 0).map(lambda x: 1 if x == True else 0).sum()
len_a = (all_games['away_score'] > 0).map(lambda x: 1 if x == True else 0).sum()
scores = {'home_score': [len_h], 'away_score': [len_a]}

# %% [markdown]
# Next, we will create a dictionary of the probability that a single scoring play results in 2,3,6,7, or 8 points.

# %%
plays = {place:{i:(all_games[[place]] == i).sum()[place]/scores[place][0] for score in [[len_h,len_a]] for i in [2,3,6,7,8]} for place in ['home_score','away_score']}
plays
# Out:
# {'home_score': {2: 0.010752688172043012,
#   3: 0.39619520264681557,
#   6: 0.04218362282878412,
#   7: 0.5153019023986766,
#   8: 0.03556658395368073},
#  'away_score': {2: 0.004651162790697674,
#   3: 0.41674418604651164,
#   6: 0.0586046511627907,
#   7: 0.4930232558139535,
#   8: 0.026976744186046512}}

# %% [markdown]
# We are also interested in how many scoring plays will occur for the home and away team. We will create a dictionary with the probability of how many scoring plays a team has.

# %%
num_scores = {place:plays_2023[plays_2023['posteam'] == plays_2023[place]].groupby('game_id',as_index = False).sum()['sp'].value_counts() for place in ['home_team','away_team']}
num_scores['home_score'] = num_scores['home_team'] / sum(num_scores['home_team'] )
num_scores['away_score'] = num_scores['away_team'] / sum(num_scores['away_team'] )
pd.DataFrame(num_scores)
# Out:
#     home_team  away_team  home_score  away_score
# sp
# 0           3        3.0    0.010791    0.010791
# 1           4       10.0    0.014388    0.035971
# 2           9       13.0    0.032374    0.046763
# 3          21       34.0    0.075540    0.122302
# 4          15       27.0    0.053957    0.097122
# 5          41       43.0    0.147482    0.154676
# 6          43       43.0    0.154676    0.154676
# 7          36       31.0    0.129496    0.111511
# 8          35       21.0    0.125899    0.075540
# 9          31       24.0    0.111511    0.086331
# 10         14       16.0    0.050360    0.057554
# 11         13        7.0    0.046763    0.025180
# 12          6        6.0    0.021583    0.021583
# 13          1        NaN    0.003597         NaN
# 14          3        NaN    0.010791         NaN
# 16          2        NaN    0.007194         NaN
# 20          1        NaN    0.003597         NaN

# %% [markdown]
# We will create a function num_sp() which uses the num_scores dictionaries above to generate how many scoring plays a team has per game for a given number of games.

# %%
rng = np.random.default_rng()
def num_sp(n,team):
    sp = rng.choice(a=list(num_scores[f"{team}_score"].index), size=n, p=list(num_scores[f"{team}_score"].values))
    return sp

# %% [markdown]
# The function games() generate a distribution of single-scoring plays.

# %%
rng = np.random.default_rng()
def games(n,team):
    i = 1
    if (team == 'home'): i = 0
    scores_in_game = rng.choice(a=list(plays[f"{team}_score"].keys()), size=n, p=pd.DataFrame(plays.values()).iloc[i])
    return scores_in_game

# %% [markdown]
# The function scores() combines the previous functions and dictionaries to print simulated scores for a certain number of games.

# %%
def scores(n):
    home_score_plays = num_sp(n,'home')
    away_score_plays = num_sp(n,'away')
    scores_list = []
    for i in range(len(home_score_plays)):
        h = int(sum(games(home_score_plays[i],'home')))
        a = int(sum(games(away_score_plays[i],'away')))
        if h < a:
            scores_list.append((h,a))
        else:
            scores_list.append((a,h))
    return scores_list

# %% [markdown]
# For instance, for a 1000 games, these are simulated scores

# %%
scores(1000)
# Out:
# [(13, 21),
#  (7, 30),
#  (26, 26),
#  (54, 57),
#  (30, 36),
#  (34, 50),
#  (10, 37),
#  (24, 38),
#  (6, 48),
#  (38, 60),
#  (24, 51),
#  (36, 70),
#  (26, 28),
#  (7, 20),
#  (13, 14),
#  (30, 31),
#  (20, 47),
#  (17, 27),
#  (13, 28),
#  (33, 71),
#  (17, 45),
#  (9, 27),
#  (27, 54),
#  (17, 33),
#  (41, 45),
#  (23, 30),
#  (13, 33),
#  (22, 65),
#  (35, 50),
#  (57, 61),
#  (35, 50),
#  (21, 40),
#  (26, 57),
#  (25, 38),
#  (40, 55),
#  (7, 17),
#  (7, 36),
#  (13, 30),
#  (29, 30),
#  (17, 37),
#  (15, 43),
#  (6, 46),
#  (22, 31),
#  (21, 39),
#  (31, 34),
#  (3, 20),
#  (24, 34),
#  (13, 16),
#  (32, 41),
#  (35, 45),
#  (55, 60),
#  (21, 36),
#  (34, 40),
#  (23, 33),
#  (24, 37),
#  (24, 38),
#  (44, 46),
#  (22, 35),
#  (39, 45),
#  (9, 17),
#  (36, 47),
#  (10, 60),
#  (16, 26),
#  (23, 37),
#  (16, 23),
#  (40, 54),
#  (21, 43),
#  (24, 43),
#  (20, 48),
#  (16, 64),
#  (29, 41),
#  (43, 46),
#  (13, 32),
#  (33, 37),
#  (31, 53),
#  (31, 33),
#  (20, 54),
#  (10, 23),
#  (36, 38),
#  (16, 53),
#  (27, 40),
#  (19, 43),
#  (43, 51),
#  (7, 17),
#  (32, 56),
#  (17, 43),
#  (6, 7),
#  (29, 48),
#  (50, 64),
#  (26, 63),
#  (38, 45),
#  (20, 47),
#  (33, 37),
#  (9, 43),
#  (21, 33),
#  (48, 62),
#  (13, 16),
#  (7, 40),
#  (22, 40),
#  (23, 34),
#  (0, 17),
#  (13, 33),
#  (21, 28),
#  (10, 55),
#  (42, 50),
#  (18, 23),
#  (23, 39),
#  (31, 40),
#  (19, 40),
#  (10, 16),
#  (3, 10),
#  (40, 53),
#  (13, 27),
#  (13, 48),
#  (39, 43),
#  (48, 113),
#  (12, 32),
#  (30, 34),
#  (39, 39),
#  (17, 78),
#  (23, 30),
#  (27, 51),
#  (9, 24),
#  (57, 58),
#  (23, 26),
#  (10, 31),
#  (43, 50),
#  (3, 51),
#  (32, 50),
#  (21, 24),
#  (31, 42),
#  (39, 51)]

# %% [markdown]
# ## Scorigami Analysis

# %% [markdown]
# A Scorigami is a final score that has never occurred in the history of the NFL. We will make a sp data frame to determine the number of scoring plays in each game of the NFL season.

# %%
sp = all_games.copy()
sp['home_score'] = sp['home_score'].map(lambda x: 1 if x>0 else 0)
sp['away_score'] = sp['away_score'].map(lambda x: 1 if x>0 else 0)
sp = sp.groupby('game_id',as_index = False).sum()
sp
# Out:
#              game_id                                        season_type  week  \
# 0    2023_01_ARI_WAS                  REGREGREGREGREGREGREGREGREGREGREG    11
# 1    2023_01_BUF_NYJ                  REGREGREGREGREGREGREGREGREGREGREG    11
# 2    2023_01_CAR_ATL                     REGREGREGREGREGREGREGREGREGREG    10
# 3    2023_01_CIN_CLE                           REGREGREGREGREGREGREGREG     8
# 4    2023_01_DAL_NYG               REGREGREGREGREGREGREGREGREGREGREGREG    12
# ..               ...                                                ...   ...
# 273   2023_19_GB_DAL  POSTPOSTPOSTPOSTPOSTPOSTPOSTPOSTPOSTPOSTPOSTPO...   437
# 274   2023_19_LA_DET  POSTPOSTPOSTPOSTPOSTPOSTPOSTPOSTPOSTPOSTPOSTPO...   266
# 275   2023_19_MIA_KC           POSTPOSTPOSTPOSTPOSTPOSTPOSTPOSTPOSTPOST   190
# 276   2023_19_PHI_TB  POSTPOSTPOSTPOSTPOSTPOSTPOSTPOSTPOSTPOSTPOSTPO...   247
# 277  2023_19_PIT_BUF  POSTPOSTPOSTPOSTPOSTPOSTPOSTPOSTPOSTPOSTPOSTPO...   266
#
#      qtr total_away_score  total_home_score  quarter_seconds_remaining  sp  \
# 0     26              111               114                     3684.0  11
# 1     33              122                97                     3236.0  11
# 2     30               73               124                     5652.0  10
# 3     24               15               107                     3549.0   8
# 4     25              266                 0                     5697.0  11
# ..   ...              ...               ...                        ...  ..
# 273   63              717               247                     7514.0  21
# 274   27              141               230                     5749.0  14
# 275   23               48               142                     6213.0  10
# 276   30               69               226                     4577.0  12
# 277   34              100               277                     5090.0  14
#
#                                                posteam  \
# 0                    WASWASARIARIWASARIWASARIWASWASWAS
# 1                    BUFNYJBUFBUFBUFNYJNYJNYJNYJBUFBUF
# 2                       ATLATLCARCARCARATLATLATLATLATL
# 3                             CLECLECLECINCLECLECLECLE
# 4                 NYGDALDALNYGDALDALDALDALDALDALDALDAL
# ..                                                 ...
# 273  GBGBGBGBGBGBDALGBDALDALDALGBGBDALDALGBGBGBGBDA...
# 274                DETDETLADETDETLALADETDETLALADETLALA
# 275                             KCKCKCMIAMIAKCKCKCKCKC
# 276                     TBTBTBTBPHITBPHIPHIPHITBTBTBTB
# 277         BUFBUFBUFBUFBUFBUFPITPITPITBUFPITPITBUFBUF
#
#                                                defteam  ... total_away_score  \
# 0                    ARIARIWASWASARIWASARIWASARIARIARI  ...              111
# 1                    NYJBUFNYJNYJNYJBUFBUFBUFBUFNYJNYJ  ...              122
# 2                       CARCARATLATLATLCARCARCARCARCAR  ...               73
# 3                             CINCINCINCLECINCINCINCIN  ...               15
# 4                 DALNYGNYGDALNYGNYGNYGNYGNYGNYGNYGNYG  ...              266
# ..                                                 ...  ...              ...
# 273  DALDALDALDALDALDALGBDALGBGBGBDALDALGBGBDALDALD...  ...              717
# 274                LALADETLALADETDETLALADETDETLADETDET  ...              141
# 275                       MIAMIAMIAKCKCMIAMIAMIAMIAMIA  ...               48
# 276                PHIPHIPHIPHITBPHITBTBTBPHIPHIPHIPHI  ...               69
# 277         PITPITPITPITPITPITBUFBUFBUFPITBUFBUFPITPIT  ...              100
#
#                                                   desc  \
# 0    (4:22) (Shotgun) 14-S.Howell pass short left t...
# 1    (3:09) 2-T.Bass 40 yard field goal is GOOD, Ce...
# 2    (15:00) (Shotgun) 9-D.Ridder pass short right ...
# 3    (14:19) 7-D.Hopkins 42 yard field goal is GOOD...
# 4    (8:14) 9-G.Gano 45 yard field goal is BLOCKED ...
# ..                                                 ...
# 273  (7:12) (Shotgun) 33-A.Jones right guard for 3 ...
# 274  (9:33) 5-D.Montgomery up the middle for 1 yard...
# 275  (11:10) (Shotgun) 15-P.Mahomes pass short righ...
# 276  (10:05) 4-C.McLaughlin 28 yard field goal is G...
# 277  (7:05) (Shotgun) 17-J.Allen pass short left to...
#
#                                              play_type safety  \
# 0    passextra_pointfield_goalfield_goalpassextra_p...    0.0
# 1    field_goalfield_goalpassextra_pointfield_goalf...    0.0
# 2    passextra_pointpassextra_pointfield_goalfield_...    0.0
# 3    field_goalrunextra_pointfield_goalfield_goalfi...    0.0
# 4    field_goalextra_pointfield_goalpassextra_point...    0.0
# ..                                                 ...    ...
# 273  runextra_pointrunextra_pointpassextra_pointpas...    0.0
# 274  runextra_pointfield_goalrunextra_pointpassextr...    0.0
# 275  passextra_pointfield_goalpassextra_pointfield_...    0.0
# 276  field_goalpassextra_pointfield_goalfield_goalf...    1.0
# 277  passextra_pointpassextra_pointrunextra_pointpa...    0.0
#
#      home_team_score away_team_score   xp  2pt  home_score  away_score
# 0                 12               6  3.0  0.0           4           4
# 1                 12               6  2.0  0.0           5           4
# 2                 18               6  4.0  0.0           4           2
# 3                 12               0  1.0  2.0           5           1
# 4                  0              30  4.0  0.0           0           7
# ..               ...             ...  ...  ...         ...         ...
# 273               24              42  7.0  4.0           5           7
# 274               18              12  5.0  0.0           4           5
# 275               12               6  3.0  0.0           6           1
# 276               18               6  3.0  0.0           7           2
# 277               24              12  6.0  0.0           5           3
#
# [278 rows x 29 columns]

# %% [markdown]
# Below is a dictionary of the likelihood of how many scoring plays a team scores in a given NFL game.

# %%
num_scores = {place:sp[place].value_counts() for place in ['home_score','away_score']}
num_scores['home_score'] = num_scores['home_score'] / sum(num_scores['home_score'] )
num_scores['away_score'] = num_scores['away_score'] / sum(num_scores['away_score'] )
num_scores
# Out:
# {'home_score': home_score
#  4     0.212230
#  5     0.212230
#  3     0.172662
#  6     0.154676
#  2     0.097122
#  7     0.075540
#  1     0.028777
#  8     0.021583
#  0     0.017986
#  10    0.003597
#  9     0.003597
#  Name: count, dtype: float64,
#  'away_score': away_score
#  4    0.241007
#  3    0.223022
#  5    0.147482
#  2    0.129496
#  6    0.122302
#  1    0.064748
#  7    0.050360
#  8    0.010791
#  0    0.010791
#  Name: count, dtype: float64}

# %% [markdown]
# We will make a data frame of all scorigamis.

# %%
pip install html5lib
# Out:
# Requirement already satisfied: html5lib in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (1.1)
# Requirement already satisfied: six>=1.9 in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (from html5lib) (1.16.0)
# Requirement already satisfied: webencodings in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (from html5lib) (0.5.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
multiser = pd.read_html('/Users/MC/Downloads/scoregami.rtf',skiprows = 2)[0].fillna(0).stack()
multiser = pd.DataFrame(multiser)
scorigami = multiser[multiser[0] == 0]
scorigami
# Out:
#          0
# 0  1   0.0
#    4   0.0
#    46  0.0
#    50  0.0
#    61  0.0
# ...    ...
# 73 69  0.0
#    70  0.0
#    71  0.0
#    72  0.0
#    73  0.0
#
# [4393 rows x 1 columns]

# %% [markdown]
# For each game, we will check if it is a scorigami. If it is, we will add it to the scori list. We will also count how many games it generates 1000 scorigamis.

# %%
scori = []
temp_array = []
counter = 0
while len(scori) < 1000:
    counter += 1
    temp = scores(1)[0]
    temp_array.append(temp)
    if temp in scorigami.index:
        scori.append(temp)
scori = pd.DataFrame({"score":scori})
counter
# Out:
# 38605

# %% [markdown]
# Finally, we will generate a histogram of scorigamis to determine which ones are the most likely to occur next.

# %%
hist = alt.Chart(scori).mark_bar().encode(
    x = alt.X('score:N',
                sort=alt.EncodingSortField(field="Letters", op="count", order='descending'),
                axis=alt.Axis(labelAngle=0)), 
    y = 'count()',
    tooltip=['score', 'count()']).interactive()
hist
# Out:
# /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages/altair/utils/core.py:395: FutureWarning: the convert_dtype parameter is deprecated and will be removed in a future version.  Do ``ser.astype(object).apply()`` instead if you want ``convert_dtype=False``.
#   col = df[col_name].apply(to_list_if_array, convert_dtype=False)
# alt.Chart(...)

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=3ba18e92-e83d-46c0-9312-ed9b128d0b76' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>

# %%
pip install -U jupyter-book
# Out:
# Requirement already satisfied: jupyter-book in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (1.0.0)
# Requirement already satisfied: click<9,>=7.1 in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (from jupyter-book) (8.1.7)
# Requirement already satisfied: Jinja2 in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (from jupyter-book) (3.1.3)
# Requirement already satisfied: jsonschema<5 in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (from jupyter-book) (4.19.2)
# Requirement already satisfied: linkify-it-py<3,>=2 in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (from jupyter-book) (2.0.0)
# Requirement already satisfied: myst-nb<3,>=1 in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (from jupyter-book) (1.1.0)
# Requirement already satisfied: myst-parser<3,>=1 in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (from jupyter-book) (2.0.0)
# Requirement already satisfied: pyyaml in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (from jupyter-book) (6.0.1)
# Requirement already satisfied: sphinx<8,>=5 in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (from jupyter-book) (7.3.7)
# Requirement already satisfied: sphinx-comments in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (from jupyter-book) (0.0.3)
# Requirement already satisfied: sphinx-copybutton in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (from jupyter-book) (0.5.2)
# Requirement already satisfied: sphinx-external-toc<2,>=1.0.1 in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (from jupyter-book) (1.0.1)
# Requirement already satisfied: sphinx-jupyterbook-latex<2,>=1 in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (from jupyter-book) (1.0.0)
# Requirement already satisfied: sphinx-design<1,>=0.5 in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (from jupyter-book) (0.6.0)
# Requirement already satisfied: sphinx-thebe<1,>=0.3 in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (from jupyter-book) (0.3.1)
# Requirement already satisfied: sphinx-book-theme<2,>=1.1.0 in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (from jupyter-book) (1.1.2)
# Requirement already satisfied: sphinx_togglebutton in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (from jupyter-book) (0.3.2)
# Requirement already satisfied: sphinxcontrib-bibtex<3,>=2.5.0 in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (from jupyter-book) (2.6.2)
# Requirement already satisfied: sphinx-multitoc-numbering<1,>=0.1.3 in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (from jupyter-book) (0.1.3)
# Requirement already satisfied: attrs>=22.2.0 in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (from jsonschema<5->jupyter-book) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (from jsonschema<5->jupyter-book) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (from jsonschema<5->jupyter-book) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (from jsonschema<5->jupyter-book) (0.10.6)
# Requirement already satisfied: uc-micro-py in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (from linkify-it-py<3,>=2->jupyter-book) (1.0.1)
# Requirement already satisfied: importlib_metadata in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (from myst-nb<3,>=1->jupyter-book) (7.0.1)
# Requirement already satisfied: ipython in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (from myst-nb<3,>=1->jupyter-book) (8.20.0)
# Requirement already satisfied: jupyter-cache>=0.5 in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (from myst-nb<3,>=1->jupyter-book) (1.0.0)
# Requirement already satisfied: nbclient in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (from myst-nb<3,>=1->jupyter-book) (0.8.0)
# Requirement already satisfied: nbformat>=5.0 in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (from myst-nb<3,>=1->jupyter-book) (5.9.2)
# Requirement already satisfied: typing-extensions in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (from myst-nb<3,>=1->jupyter-book) (4.9.0)
# Requirement already satisfied: ipykernel in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (from myst-nb<3,>=1->jupyter-book) (6.28.0)
# Requirement already satisfied: docutils<0.21,>=0.16 in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (from myst-parser<3,>=1->jupyter-book) (0.20.1)
# Requirement already satisfied: markdown-it-py~=3.0 in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (from myst-parser<3,>=1->jupyter-book) (3.0.0)
# Requirement already satisfied: mdit-py-plugins~=0.4 in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (from myst-parser<3,>=1->jupyter-book) (0.4.1)
# Requirement already satisfied: sphinxcontrib-applehelp in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (from sphinx<8,>=5->jupyter-book) (1.0.2)
# Requirement already satisfied: sphinxcontrib-devhelp in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (from sphinx<8,>=5->jupyter-book) (1.0.2)
# Requirement already satisfied: sphinxcontrib-jsmath in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (from sphinx<8,>=5->jupyter-book) (1.0.1)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.0 in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (from sphinx<8,>=5->jupyter-book) (2.0.0)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.9 in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (from sphinx<8,>=5->jupyter-book) (1.1.10)
# Requirement already satisfied: sphinxcontrib-qthelp in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (from sphinx<8,>=5->jupyter-book) (1.0.3)
# Requirement already satisfied: Pygments>=2.14 in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (from sphinx<8,>=5->jupyter-book) (2.15.1)
# Requirement already satisfied: snowballstemmer>=2.0 in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (from sphinx<8,>=5->jupyter-book) (2.2.0)
# Requirement already satisfied: babel>=2.9 in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (from sphinx<8,>=5->jupyter-book) (2.11.0)
# Requirement already satisfied: alabaster~=0.7.14 in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (from sphinx<8,>=5->jupyter-book) (0.7.16)
# Requirement already satisfied: imagesize>=1.3 in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (from sphinx<8,>=5->jupyter-book) (1.4.1)
# Requirement already satisfied: requests>=2.25.0 in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (from sphinx<8,>=5->jupyter-book) (2.31.0)
# Requirement already satisfied: packaging>=21.0 in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (from sphinx<8,>=5->jupyter-book) (23.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (from Jinja2->jupyter-book) (2.1.3)
# Requirement already satisfied: pydata-sphinx-theme>=0.14 in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (from sphinx-book-theme<2,>=1.1.0->jupyter-book) (0.15.3)
# Requirement already satisfied: pybtex>=0.24 in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (from sphinxcontrib-bibtex<3,>=2.5.0->jupyter-book) (0.24.0)
# Requirement already satisfied: pybtex-docutils>=1.0.0 in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (from sphinxcontrib-bibtex<3,>=2.5.0->jupyter-book) (1.0.3)
# Requirement already satisfied: setuptools in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (from sphinx_togglebutton->jupyter-book) (68.2.2)
# Requirement already satisfied: wheel in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (from sphinx_togglebutton->jupyter-book) (0.41.2)
# Requirement already satisfied: pytz>=2015.7 in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (from babel>=2.9->sphinx<8,>=5->jupyter-book) (2023.3.post1)
# Requirement already satisfied: sqlalchemy<3,>=1.3.12 in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (from jupyter-cache>=0.5->myst-nb<3,>=1->jupyter-book) (2.0.25)
# Requirement already satisfied: tabulate in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (from jupyter-cache>=0.5->myst-nb<3,>=1->jupyter-book) (0.9.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (from markdown-it-py~=3.0->myst-parser<3,>=1->jupyter-book) (0.1.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (from nbclient->myst-nb<3,>=1->jupyter-book) (7.4.9)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (from nbclient->myst-nb<3,>=1->jupyter-book) (5.5.0)
# Requirement already satisfied: traitlets>=5.4 in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (from nbclient->myst-nb<3,>=1->jupyter-book) (5.7.1)
# Requirement already satisfied: fastjsonschema in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (from nbformat>=5.0->myst-nb<3,>=1->jupyter-book) (2.16.2)
# Requirement already satisfied: latexcodec>=1.0.4 in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (from pybtex>=0.24->sphinxcontrib-bibtex<3,>=2.5.0->jupyter-book) (3.0.0)
# Requirement already satisfied: six in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (from pybtex>=0.24->sphinxcontrib-bibtex<3,>=2.5.0->jupyter-book) (1.16.0)
# Requirement already satisfied: beautifulsoup4 in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (from pydata-sphinx-theme>=0.14->sphinx-book-theme<2,>=1.1.0->jupyter-book) (4.12.2)
# Requirement already satisfied: accessible-pygments in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (from pydata-sphinx-theme>=0.14->sphinx-book-theme<2,>=1.1.0->jupyter-book) (0.0.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (from requests>=2.25.0->sphinx<8,>=5->jupyter-book) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (from requests>=2.25.0->sphinx<8,>=5->jupyter-book) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (from requests>=2.25.0->sphinx<8,>=5->jupyter-book) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (from requests>=2.25.0->sphinx<8,>=5->jupyter-book) (2024.2.2)
# Requirement already satisfied: zipp>=0.5 in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (from importlib_metadata->myst-nb<3,>=1->jupyter-book) (3.17.0)
# Requirement already satisfied: appnope in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (from ipykernel->myst-nb<3,>=1->jupyter-book) (0.1.2)
# Requirement already satisfied: comm>=0.1.1 in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (from ipykernel->myst-nb<3,>=1->jupyter-book) (0.1.2)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (from ipykernel->myst-nb<3,>=1->jupyter-book) (1.6.7)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (from ipykernel->myst-nb<3,>=1->jupyter-book) (0.1.6)
# Requirement already satisfied: nest-asyncio in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (from ipykernel->myst-nb<3,>=1->jupyter-book) (1.6.0)
# Requirement already satisfied: psutil in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (from ipykernel->myst-nb<3,>=1->jupyter-book) (5.9.0)
# Requirement already satisfied: pyzmq>=24 in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (from ipykernel->myst-nb<3,>=1->jupyter-book) (24.0.1)
# Requirement already satisfied: tornado>=6.1 in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (from ipykernel->myst-nb<3,>=1->jupyter-book) (6.3.3)
# Requirement already satisfied: decorator in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (from ipython->myst-nb<3,>=1->jupyter-book) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (from ipython->myst-nb<3,>=1->jupyter-book) (0.18.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (from ipython->myst-nb<3,>=1->jupyter-book) (3.0.43)
# Requirement already satisfied: stack-data in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (from ipython->myst-nb<3,>=1->jupyter-book) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (from ipython->myst-nb<3,>=1->jupyter-book) (4.8.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (from jedi>=0.16->ipython->myst-nb<3,>=1->jupyter-book) (0.8.3)
# Requirement already satisfied: entrypoints in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (from jupyter-client>=6.1.12->nbclient->myst-nb<3,>=1->jupyter-book) (0.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (from jupyter-client>=6.1.12->nbclient->myst-nb<3,>=1->jupyter-book) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5 in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (from jupyter-core!=5.0.*,>=4.12->nbclient->myst-nb<3,>=1->jupyter-book) (3.10.0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (from pexpect>4.3->ipython->myst-nb<3,>=1->jupyter-book) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython->myst-nb<3,>=1->jupyter-book) (0.2.5)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (from sqlalchemy<3,>=1.3.12->jupyter-cache>=0.5->myst-nb<3,>=1->jupyter-book) (3.0.1)
# Requirement already satisfied: soupsieve>1.2 in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (from beautifulsoup4->pydata-sphinx-theme>=0.14->sphinx-book-theme<2,>=1.1.0->jupyter-book) (2.5)
# Requirement already satisfied: executing in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (from stack-data->ipython->myst-nb<3,>=1->jupyter-book) (0.8.3)
# Requirement already satisfied: asttokens in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (from stack-data->ipython->myst-nb<3,>=1->jupyter-book) (2.0.5)
# Requirement already satisfied: pure-eval in /Users/mc/Downloads/anaconda3/lib/python3.11/site-packages (from stack-data->ipython->myst-nb<3,>=1->jupyter-book) (0.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
jupyter-book create book/
# Out:
#   Cell In[35], line 1
#     jupyter-book create book/
#                  ^
# SyntaxError: invalid syntax
